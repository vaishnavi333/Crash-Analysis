# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\sushm\Downloads\RawData DV.csv")
df
# Out:
#         Crash_ID       CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 0              1   9/5/2023 19:05                  30         TRAFFIC SIGNAL
# 1              2  9/22/2023 18:45                  50            NO CONTROLS
# 2              3  7/29/2023 14:45                  30         TRAFFIC SIGNAL
# 3              4   8/9/2023 23:00                  30            NO CONTROLS
# 4              5  8/18/2023 12:50                  15                  OTHER
# ...          ...              ...                 ...                    ...
# 821415    821416   3/6/2024 15:10                  35         TRAFFIC SIGNAL
# 821416    821417   3/6/2024 14:18                  25            NO CONTROLS
# 821417    821418    3/6/2024 0:01                  30            NO CONTROLS
# 821418    821419   3/4/2019 18:40                  30            NO CONTROLS
# 821419    821420  5/31/2023 17:00                  15                UNKNOWN
#
# ...

# %%
df.drop(columns=['REPORT_TYPE'], inplace=True)

df
# Out:
#         Crash_ID       CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 0              1   9/5/2023 19:05                  30         TRAFFIC SIGNAL
# 1              2  9/22/2023 18:45                  50            NO CONTROLS
# 2              3  7/29/2023 14:45                  30         TRAFFIC SIGNAL
# 3              4   8/9/2023 23:00                  30            NO CONTROLS
# 4              5  8/18/2023 12:50                  15                  OTHER
# ...          ...              ...                 ...                    ...
# 821415    821416   3/6/2024 15:10                  35         TRAFFIC SIGNAL
# 821416    821417   3/6/2024 14:18                  25            NO CONTROLS
# 821417    821418    3/6/2024 0:01                  30            NO CONTROLS
# 821418    821419   3/4/2019 18:40                  30            NO CONTROLS
# 821419    821420  5/31/2023 17:00                  15                UNKNOWN
#
# ...

# %%
df.isna().sum()
# Out:
# Crash_ID                            0
# CRASH_DATE                          0
# POSTED_SPEED_LIMIT                  0
# TRAFFIC_CONTROL_DEVICE              0
# DEVICE_CONDITION                    0
# WEATHER_CONDITION                   0
# LIGHTING_CONDITION                  0
# FIRST_CRASH_TYPE                    0
# TRAFFICWAY_TYPE                     0
# ALIGNMENT                           0
# ROADWAY_SURFACE_COND                0
# ROAD_DEFECT                         0
# CRASH_TYPE                          0
# DAMAGE                              0
# DATE_POLICE_NOTIFIED                0
# PRIM_CONTRIBUTORY_CAUSE             0
# SEC_CONTRIBUTORY_CAUSE              0
# STREET_NO                           0
# STREET_DIRECTION                    4
# STREET_NAME                         1
# MOST_SEVERE_INJURY               1805
# INJURIES_TOTAL                   1793
# INJURIES_FATAL                   1793
# INJURIES_INCAPACITATING          1793
# INJURIES_NON_INCAPACITATING      1793
# ...

# %%
df = df.dropna(subset=['MOST_SEVERE_INJURY'])

df = df.dropna(subset=['LATITUDE'])
df.isna().sum()
# Out:
# Crash_ID                         0
# CRASH_DATE                       0
# POSTED_SPEED_LIMIT               0
# TRAFFIC_CONTROL_DEVICE           0
# DEVICE_CONDITION                 0
# WEATHER_CONDITION                0
# LIGHTING_CONDITION               0
# FIRST_CRASH_TYPE                 0
# TRAFFICWAY_TYPE                  0
# ALIGNMENT                        0
# ROADWAY_SURFACE_COND             0
# ROAD_DEFECT                      0
# CRASH_TYPE                       0
# DAMAGE                           0
# DATE_POLICE_NOTIFIED             0
# PRIM_CONTRIBUTORY_CAUSE          0
# SEC_CONTRIBUTORY_CAUSE           0
# STREET_NO                        0
# STREET_DIRECTION                 1
# STREET_NAME                      0
# MOST_SEVERE_INJURY               0
# INJURIES_TOTAL                   0
# INJURIES_FATAL                   0
# INJURIES_INCAPACITATING          0
# INJURIES_NON_INCAPACITATING      0
# INJURIES_REPORTED_NOT_EVIDENT    0
# INJURIES_NO_INDICATION           0
# ...

# %%
df.shape
# Out:
# (813972, 34)

# %%
df.to_csv(r"C:\Users\sushm\Downloads\DV_datasets\df.csv", index=False)
print("done")
# Out:
# done

# %%
#importing the cleaned dataset
df_cleaned = pd.read_csv(r"C:\Users\sushm\Downloads\DV_datasets\df.csv")

crash_file = df_cleaned[['Crash_ID', 'CRASH_DATE', 'CRASH_TYPE', 'CRASH_HOUR', 'CRASH_DAY_OF_WEEK', 'CRASH_MONTH', 'POSTED_SPEED_LIMIT', 'FIRST_CRASH_TYPE', 'TRAFFICWAY_TYPE', 'TRAFFIC_CONTROL_DEVICE', 'DEVICE_CONDITION']]

#saving crash dataset
crash_file.to_csv(r"C:\Users\sushm\Downloads\DV_datasets\crash.csv", index=False)
print("done")
# Out:
# done

# %%
crash_location_file = df_cleaned[['Crash_ID', 'STREET_NO', 'STREET_DIRECTION', 'STREET_NAME', 'LONGITUDE', 'LATITUDE', 'LOCATION', 'ROADWAY_SURFACE_COND', 'ROAD_DEFECT']]

#saving crash location dataset
crash_location_file.to_csv(r"C:\Users\sushm\Downloads\DV_datasets\crash_location.csv", index=False)
print("done")
# Out:
# done

# %%
crash_injury_file = df_cleaned[['Crash_ID', 'MOST_SEVERE_INJURY', 'INJURIES_TOTAL', 'INJURIES_FATAL', 'INJURIES_INCAPACITATING', 'INJURIES_NON_INCAPACITATING']]

#saving crash location dataset
crash_injury_file.to_csv(r"C:\Users\sushm\Downloads\DV_datasets\crash_injury.csv", index=False)
print("done")
# Out:
# done

# %%
crash_weather_file = df_cleaned[['Crash_ID', 'WEATHER_CONDITION', 'LIGHTING_CONDITION']]

#saving crash location dataset
crash_weather_file.to_csv(r"C:\Users\sushm\Downloads\DV_datasets\crash_weather.csv", index=False)
print("done")
# Out:
# done

# %%
crash_cause_file = df_cleaned[['Crash_ID', 'PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE', 'DAMAGE']]

#saving crash location dataset
crash_cause_file.to_csv(r"C:\Users\sushm\Downloads\DV_datasets\crash_cause.csv", index=False)
print("done")
# Out:
# done
